# %% [markdown]
# # MiBiPreT Data Analysis Notebook
#
# This notebook demonstrates step-by-step how to load, standardize, and analyze data using MiBiPreT functions. Each code cell is preceded by an explanation of its purpose.

# %% [markdown]
# ### 1. Import the `screening_NA` Module
# This module contains functions for NA screening analysis.

# %%
import mibipret.analysis.sample.screening_NA as na

# %% [markdown]
# ### 2. Import the `standardize` Function
# Import the function that standardizes the dataset from the data check module.

# %%
from mibipret.data.check_data import standardize

# %% [markdown]
# ### 3. Import the `load_csv` Function
# This function will load the CSV file containing the raw data.

# %%
from mibipret.data.load_data import load_csv

# %% [markdown]
# ### 4. Import the `display` Function
# The `display` function from IPython is used to render outputs nicely in the notebook.

# %%
from IPython.display import display

# %% [markdown]
# ### 5. Define the CSV File Path
# Set the path to the CSV file containing your data.

# %%
file_path = "../data/cleaned/na_screening/cw_T2_BTEXN.csv"

# %% [markdown]
# ### 6. Load the CSV Data
# Load the raw data and the associated units from the CSV file using the `load_csv` function.

# %%
data_raw, units = load_csv(file_path, verbose=True)
# Out:
# ================================================================
#  Running function 'load_csv()' on data file  ../data/cleaned/na_screening/cw_T2_BTEXN.csv
# ================================================================
# Units of quantities:
# -------------------
#   sample_nr obs_well Benzene Toluene Ethylbenzene O Xylene P/M Xylene  \
# 0       NaN      NaN    ug/l    ug/l         ug/l     ug/l       ug/l
#
#   Naphthalene Acenaphthylene depth  ...    O2 Redox Fe II    Mn chloride  \
# 0        ug/l           ug/l     m  ...  mg/l    mV  mg/l  mg/l     mg/l
#
#   nitrite Nitrite - N nitrate nitrate - N sulfate
# 0    mg/l        mg/l    mg/l        mg/l    mg/l
#
# [1 rows x 21 columns]
# ________________________________________________________________
# Loaded data as pandas DataFrame:
# --------------------------------
#       sample_nr     obs_well Benzene Toluene Ethylbenzene O Xylene P/M Xylene  \
# 0           NaN          NaN    ug/l    ug/l         ug/l     ug/l       ug/l
# 1    NL_CW_W_11  CW1_EFF-1-2     140       0           73       40         17
# 2    NL_CW_W_12  CW1MF09-1-3     330       0          130      140         65
# 3    NL_CW_W_13  CW1MF10-1-3     560       0          370      220        130
# 4    NL_CW_W_14  CW1MF06-1-2     550      75          440      180        190
# 5    NL_CW_W_15     IINF-1-2     610     140          690      260        450
# 6    NL_CW_W_16  CW1MF01-1-3     480       0          480      270        140
# 7    NL_CW_W_17  CW1MF02-1-3     480      60          360      190        220
# 8    NL_CW_W_18  CW1MF05-1-2     570      11          450      250        150
# 9    NL_CW_W_19  CW2MF05-1-2     110       1           24       13          9
# 10  NL_CW_W_110  CW2MF06-1-2     580      31          420      210        230
# 11  NL_CW_W_111  CW2_EFF-1-3     670      14          410      250        200
# 12  NL_CW_W_112  CW2MF01-1-2     530       0          500      230        180
# 13  NL_CW_W_113  CW2MF02-1-2     520      97          470      200        300
# 14  NL_CW_W_114  CW2MF09-1-2     570      12          260      130        110
# 15  NL_CW_W_115  CW2MF10-1-2     660      34          400      210        190
# 16  NL_CW_W_116  CW3_EFF-1-2     230       7          190       65         44
# 17  NL_CW_W_117  CW3MF01-1-2     550      13          140      110         59
# 18  NL_CW_W_118  CW3MF02-1-2     590      49          650      240        280
# 19  NL_CW_W_119  CW3MF05-1-2       3       0            4        2          2
# 20  NL_CW_W_120  CW3MF06-1-2     450      29          320      150        130
# 21  NL_CW_W_121  CW3MF09-1-2     170       1           25       13          6
# 22  NL_CW_W_122  CW3MF10-1-2     750      38          550      240        200
#
#    Naphthalene Acenaphthylene depth  ...    O2  Redox Fe II    Mn chloride  \
# 0         ug/l           ug/l     m  ...  mg/l     mV  mg/l  mg/l     mg/l
# 1          150             25     0  ...   4.5    -80    10   3,3       58
# 2          320           <0,1     0  ...  3.08   -108    23   3,6       65
# 3         1700             85     0  ...  0.42   -112   1,7   1,6       67
# 4         1800            120     0  ...  0.39   -139   2,2   0,9       67
# 5         3700            250     0  ...     0      0   1,2   0,9       68
# 6            5           <0,1     0  ...   2.3   -123    23   3,9       67
# 7         2600            140     0  ...  0.39   -153   0,4   0,9       68
# 8          840           <0,1     0  ...   3.1   -122    23   4,0       67
# 9            1           <0,1     0  ...   0.6   -152    35   6,7       62
# 10         280             38     0  ...  0.37   -142   4,2   2,0       67
# 11         350            110     0  ...  0.51    -87   1,4   1,2       67
# 12         510           <0,1     0  ...  3.51    -99    12   2,6       68
# 13        1200            130     0  ...  0.36  -1.35   0,6   1,0       68
# 14         110            2,3     0  ...   5.7   -122    21   4,0       62
# 15         710             58     0  ...  0.49   -115   2,4   2,1       67
# 16           1            1,8     0  ...  0.52    -82   1,1   0,5       51
# 17           0           0,11     0  ...   4.3   -106    25   3,8       63
# 18        1400             80     0  ...  0.49   -145   0,5   0,8       70
# 19           0           <0,1     0  ...   6.9    -89   2,5   6,9       68
# 20         270             25     0  ...    42   -112   0,8   0,9       70
# 21           3           0,20     0  ...   5.3    -89    24   3,6       62
# 22        2100             78     0  ...  0.61   -105   3,4   1,3       69
#
#    nitrite Nitrite - N nitrate nitrate - N sulfate
# 0     mg/l        mg/l    mg/l        mg/l    mg/l
# 1        0           0       0           0      16
# 2        0           0       0           0       0
# 3        0           0       0           0      50
# 4        0           0       0           0      42
# 5        0           0       0           0      81
# 6        0           0       0           0      32
# 7        0           0       0           0      68
# 8        0           0       0           0      16
# 9        0           0       0           0       0
# 10       0           0       0           0      40
# 11       0           0       0           0      55
# 12       0           0       0           0      54
# 13       0           0       0           0      68
# 14       0           0       0           0       0
# 15       0           0       0           0      42
# 16       0           0       0           0      31
# 17       0           0       0           0       0
# 18       0           0       0           0      58
# 19       0           0       0           0      10
# 20       0           0       0           0      61
# 21       0           0       0           0       0
# 22       0           0       0           0      46
#
# [23 rows x 21 columns]
# ================================================================

# %% [markdown]
# ### 7. Standardize the Data
# Standardize the raw data to ensure consistency in column names, units, and measurement values.

# %%
data, units = standardize(data_raw, reduce=True, verbose=True)
# Out:
# ================================================================
#  Running function 'standardize()' on data
# ================================================================
#  Function performing check of data including:
#   * check of column names and standardizing them.
#   * check of units and outlining which to adapt.
#   * check of values, replacing empty values by nan
#     and making them numeric
# ==============================================================
#  Running function 'check_columns()' on data
# ==============================================================
# 18 quantities identified in provided data.
# List of names with standard names:
# ----------------------------------
# sample_nr  -->  sample_nr
# obs_well  -->  obs_well
# Benzene  -->  benzene
# Toluene  -->  toluene
# Ethylbenzene  -->  ethylbenzene
# O Xylene  -->  o_xylene
# P/M Xylene  -->  pm_xylene
# Naphthalene  -->  naphthalene
# depth  -->  depth
# pH  -->  pH
# O2  -->  oxygen
# Redox  -->  redoxpot
# Fe II  -->  iron2
# Mn  -->  manganese
# chloride  -->  chloride
# nitrite  -->  nitrite
# nitrate  -->  nitrate
# sulfate  -->  sulfate
# ----------------------------------
# Identified column names have been standardized
# ________________________________________________________________
# 3 quantities have not been identified in provided data:
# ---------------------------------------------------------
# Acenaphthylene
# Nitrite - N
# nitrate - N
# ---------------------------------------------------------
# Not identified quantities have been removed from data frame
# ================================================================
# ================================================================
#  Running function 'check_units()' on data
# ================================================================
# ________________________________________________________________
#  All identified quantities given in requested units.
# ================================================================
# ================================================================
#  Running function 'check_values()' on data
# ================================================================
# WARNING: Cound not transform 'sample_nr' to numerical values
# ________________________________________________________________
# WARNING: Cound not transform 'obs_well' to numerical values
# ________________________________________________________________
# WARNING: Cound not transform 'iron2' to numerical values
# ________________________________________________________________
# WARNING: Cound not transform 'manganese' to numerical values
# ________________________________________________________________
# Quantities with values transformed to numerical (int/float):
# -----------------------------------------------------------
# benzene
# toluene
# ethylbenzene
# o_xylene
# pm_xylene
# naphthalene
# depth
# pH
# oxygen
# redoxpot
# chloride
# nitrite
# nitrate
# sulfate
# ================================================================
# ================================================================

# %% [markdown]
# ### 8. Calculate Total Reduction
# Calculate the total reduction for the 'ONS' electron acceptor group using the `reductors` function.

# %%
tot_redct = na.reductors(data, verbose=True, ea_group="ONS")
# Out:
# ==============================================================
#  Running function 'reductors()' on data
# ==============================================================
# Total amount of electron reductors per well in [mmol e-/l] is:
# 1      1.894446
# 2      0.385000
# 3      4.214831
# 4      3.545108
# 5      6.742976
# 6      2.951392
# 7      5.709520
# 8      1.719446
# 9      0.075000
# 10     3.376115
# 11     4.642314
# 12     4.934067
# 13     5.705770
# 14     0.712500
# 15     3.557608
# 16     2.645645
# 17     0.537500
# 18     4.889554
# 19     1.694966
# 20    10.328044
# 21     0.662500
# 22     3.905594
# Name: total_reductors, dtype: float64
# ----------------------------------------------------------------

# %% [markdown]
# ### 9. Calculate Total Oxidation
# Calculate the total oxidation for the 'BTEX' contaminant group using the `oxidators` function.

# %%
tot_oxi = na.oxidators(data, verbose=True, contaminant_group="BTEX")
# Out:
# ==============================================================
#  Running function 'oxidators()' on data
# ==============================================================
# Total amount of oxidators per well in [mmol e-/l] is:
# 1     0.105356
# 2     0.259659
# 3     0.500668
# 4     0.561830
# 5     0.844115
# 6     0.537257
# 7     0.513188
# 8     0.560328
# 9     0.060925
# 10    0.575962
# 11    0.603925
# 12    0.564412
# 13    0.622296
# 14    0.422040
# 15    0.584132
# 16    0.209672
# 17    0.339059
# 18    0.709682
# 19    0.004324
# 20    0.422161
# 21    0.083210
# 22    0.695595
# Name: total_oxidators, dtype: float64
# -----------------------------------------------------

# %% [markdown]
# ### 10. Compute Electron Balance
# Compute the electron balance of the standardized data using the `electron_balance` function.

# %%
e_bal = na.electron_balance(data, verbose=True)
# Out:
# ==============================================================
#  Running function 'electron_balance()' on data
# ==============================================================
# WARNING: No data on indane given, zero concentration assumed.
# ________________________________________________________________
# WARNING: No data on indene given, zero concentration assumed.
# ________________________________________________________________
# Electron balance e_red/e_cont is:
# 1      11.722651
# 2       1.014068
# 3       3.703172
# 4       2.866286
# 5       3.021568
# 6       5.474341
# 7       3.836558
# 8       1.964346
# 9       1.223483
# 10      4.957860
# 11      6.314568
# 12      6.529462
# 13      5.321077
# 14      1.537915
# 15      4.183543
# 16     12.595469
# 17      1.585268
# 18      3.960173
# 19    392.021383
# 20     19.732202
# 21      7.855587
# 22      2.633408
# Name: e_balance, dtype: float64
# ---------------------------------

# %% [markdown]
# ### 11. Analyze NA Traffic
# Analyze the NA traffic in the dataset using the `NA_traffic` function.

# %%
na_traffic = na.NA_traffic(data, verbose=True)
# Out:
# ==============================================================
#  Running function 'NA_traffic()' on data
# ==============================================================
# WARNING: No data on indane given, zero concentration assumed.
# ________________________________________________________________
# WARNING: No data on indene given, zero concentration assumed.
# ________________________________________________________________
# Evaluation if natural attenuation (NA) is ongoing:
# --------------------------------------------------
# Red light: Reduction is limited at 0 out of 22 locations
# Green light: Reduction is limited at 22 out of 22 locations
# Yellow light: No decision possible at 0 out of 22 locations
# ________________________________________________________________

# %% [markdown]
# ### 12. Calculate Total Contaminant Concentration
# Calculate the total contaminant concentration for the 'BTEX' group using the `total_contaminant_concentration` function.

# %%
tot_cont = na.total_contaminant_concentration(data, verbose=True, contaminant_group="BTEX")
# Out:
# ==============================================================
#  Running function 'total_contaminant_concentration()' on data
# ==============================================================
# Total concentration of BTEX in [ug/l] is:
# 1      270.0
# 2      665.0
# 3     1280.0
# 4     1435.0
# 5     2150.0
# 6     1370.0
# 7     1310.0
# 8     1431.0
# 9      157.0
# 10    1471.0
# 11    1544.0
# 12    1440.0
# 13    1587.0
# 14    1082.0
# 15    1494.0
# 16     536.0
# 17     872.0
# 18    1809.0
# 19      11.0
# 20    1079.0
# 21     215.0
# 22    1778.0
# Name: total_contaminants, dtype: float64
# --------------------------------------------------

# %% [markdown]
# ### 13. Determine Thresholds for Intervention
# Determine the thresholds for intervention for the 'BTEX' group using the `thresholds_for_intervention` function.

# %%
na_interventation = na.thresholds_for_intervention(data, verbose=True, contaminant_group="BTEX")
# Out:
# ==============================================================
#  Running function 'thresholds_for_intervention()' on data
# ==============================================================
# Evaluation of contaminant concentrations exceeding intervention values for BTEX:
# ------------------------------------------------------------------------------------
# Red light: Intervention values exceeded for 21 out of 22 locations
# green light: Concentrations below intervention values at 1 out of 22 locations
# Yellow light: No decision possible at 0 out of 22 locations
# ________________________________________________________________

# %% [markdown]
# ### 14. Display Thresholds for Intervention
# Display the calculated thresholds for intervention.

# %%
data_na = na.screening_NA(data)
display(data_na)
# Out:
# WARNING: No data on indane given, zero concentration assumed.
# ________________________________________________________________
# WARNING: No data on indene given, zero concentration assumed.
# ________________________________________________________________
# WARNING: No data on indane given, zero concentration assumed.
# ________________________________________________________________
# WARNING: No data on indene given, zero concentration assumed.
# ________________________________________________________________
# WARNING: No data on indane given, zero concentration assumed.
# ________________________________________________________________
# WARNING: No data on indene given, zero concentration assumed.
# ________________________________________________________________
# WARNING: No data on indane given, zero concentration assumed.
# ________________________________________________________________
# WARNING: No data on indene given, zero concentration assumed.
# ________________________________________________________________
# WARNING: No data on indane given, zero concentration assumed.
# ________________________________________________________________
# WARNING: No data on indene given, zero concentration assumed.
# ________________________________________________________________
#       sample_nr     obs_well  total_reductors  total_oxidators   e_balance  \
# 1    NL_CW_W_11  CW1_EFF-1-2         1.894446         0.161606   11.722651
# 2    NL_CW_W_12  CW1MF09-1-3         0.385000         0.379659    1.014068
# 3    NL_CW_W_13  CW1MF10-1-3         4.214831         1.138168    3.703172
# 4    NL_CW_W_14  CW1MF06-1-2         3.545108         1.236830    2.866286
# 5    NL_CW_W_15     IINF-1-2         6.742976         2.231615    3.021568
# 6    NL_CW_W_16  CW1MF01-1-3         2.951392         0.539132    5.474341
# 7    NL_CW_W_17  CW1MF02-1-3         5.709520         1.488188    3.836558
# 8    NL_CW_W_18  CW1MF05-1-2         1.719446         0.875328    1.964346
# 9    NL_CW_W_19  CW2MF05-1-2         0.075000         0.061300    1.223483
# 10  NL_CW_W_110  CW2MF06-1-2         3.376115         0.680962    4.957860
# 11  NL_CW_W_111  CW2_EFF-1-3         4.642314         0.735175    6.314568
# 12  NL_CW_W_112  CW2MF01-1-2         4.934067         0.755662    6.529462
# 13  NL_CW_W_113  CW2MF02-1-2         5.705770         1.072296    5.321077
# 14  NL_CW_W_114  CW2MF09-1-2         0.712500         0.463290    1.537915
# 15  NL_CW_W_115  CW2MF10-1-2         3.557608         0.850382    4.183543
# 16  NL_CW_W_116  CW3_EFF-1-2         2.645645         0.210047   12.595469
# 17  NL_CW_W_117  CW3MF01-1-2         0.537500         0.339059    1.585268
# 18  NL_CW_W_118  CW3MF02-1-2         4.889554         1.234682    3.960173
# 19  NL_CW_W_119  CW3MF05-1-2         1.694966         0.004324  392.021383
# 20  NL_CW_W_120  CW3MF06-1-2        10.328044         0.523411   19.732202
# 21  NL_CW_W_121  CW3MF09-1-2         0.662500         0.084335    7.855587
# 22  NL_CW_W_122  CW3MF10-1-2         3.905594         1.483095    2.633408
#
#    na_traffic_light  total_contaminants intervention_traffic  \
# 1             green               420.0                  red
# 2             green               985.0                  red
# 3             green              2980.0                  red
# 4             green              3235.0                  red
# 5             green              5850.0                  red
# 6             green              1375.0                  red
# 7             green              3910.0                  red
# 8             green              2271.0                  red
# 9             green               158.0                  red
# 10            green              1751.0                  red
# 11            green              1894.0                  red
# 12            green              1950.0                  red
# 13            green              2787.0                  red
# 14            green              1192.0                  red
# 15            green              2204.0                  red
# 16            green               537.0                  red
# 17            green               872.0                  red
# 18            green              3209.0                  red
# 19            green                11.0                green
# 20            green              1349.0                  red
# 21            green               218.0                  red
# 22            green              3878.0                  red
#
#     intervention_number                          intervention_contaminants
# 1                     2                             [benzene, naphthalene]
# 2                     3                   [benzene, o_xylene, naphthalene]
# 3                     5  [benzene, ethylbenzene, pm_xylene, o_xylene, n...
# 4                     5  [benzene, ethylbenzene, pm_xylene, o_xylene, n...
# 5                     5  [benzene, ethylbenzene, pm_xylene, o_xylene, n...
# 6                     4       [benzene, ethylbenzene, pm_xylene, o_xylene]
# 7                     5  [benzene, ethylbenzene, pm_xylene, o_xylene, n...
# 8                     5  [benzene, ethylbenzene, pm_xylene, o_xylene, n...
# 9                     1                                          [benzene]
# 10                    5  [benzene, ethylbenzene, pm_xylene, o_xylene, n...
# 11                    5  [benzene, ethylbenzene, pm_xylene, o_xylene, n...
# 12                    5  [benzene, ethylbenzene, pm_xylene, o_xylene, n...
# 13                    5  [benzene, ethylbenzene, pm_xylene, o_xylene, n...
# 14                    5  [benzene, ethylbenzene, pm_xylene, o_xylene, n...
# 15                    5  [benzene, ethylbenzene, pm_xylene, o_xylene, n...
# 16                    2                            [benzene, ethylbenzene]
# 17                    2                                [benzene, o_xylene]
# 18                    5  [benzene, ethylbenzene, pm_xylene, o_xylene, n...
# 19                    0                                                 []
# 20                    5  [benzene, ethylbenzene, pm_xylene, o_xylene, n...
# 21                    1                                          [benzene]
# 22                    5  [benzene, ethylbenzene, pm_xylene, o_xylene, n...
